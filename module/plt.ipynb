# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# D:\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
x = np.linspace(-1,1,100)#从-1到1生成100个点
y= 2*x + 1
plt.figure()
plt.plot(x,y)
plt.show()

# %%
y2 = x**2
plt.plot(x,y2)
plt.show()

# %%
x = np.linspace(-1,1,100)#从-1到1生成100个点
y= 2*x + 1
y2 = x**2

plt.figure(figsize=(2,2))
plt.plot(x,y)

plt.figure()
plt.plot(x,y2)
plt.show()

# %%
plt.plot(x,y,color='red',linewidth=1.0,linestyle='--')
plt.plot(x,y2,color='gray',linewidth=2.0,linestyle='-')
plt.show()

# %% [raw]
# 设置坐标轴

# %%
x = np.linspace(-3,3,100)#从-1到1生成100个点
y1= 2*x + 1
y2 = x**2
plt.figure(figsize=(9,6))
#设置坐标轴
plt.xlim((-1,2))
plt.ylim((-2,3))

plt.xlabel('xxx')
plt.ylabel('yyy')
plt.title('title')

plt.plot(x,y1,color='red',linewidth=1.0,linestyle='--')
plt.plot(x,y2,color='gray',linewidth=2.0,linestyle='-')
plt.show()

# %%
new_data = np.linspace(-2,2,10)
print(new_data)
# Out:
# [-2.         -1.55555556 -1.11111111 -0.66666667 -0.22222222  0.22222222
#   0.66666667  1.11111111  1.55555556  2.        ]

# %%
x = np.linspace(-3,3,100)#从-1到1生成100个点
y1= 2*x + 1
y2 = x**2
plt.figure(figsize=(9,6))
#设置坐标轴
plt.xlim((-1,2))
plt.ylim((-2,3))

plt.xlabel('xxx')
plt.ylabel('yyy')
plt.title('title')

plt.plot(x,y1,color='red',linewidth=1.0,linestyle='--')
plt.plot(x,y2,color='gray',linewidth=2.0,linestyle='-')

plt.xticks(new_data)
plt.yticks([-1,0,1,2,3],['level1','level2','level3','level4','level5'])
plt.show()

# %%
x = np.linspace(-3,3,100)#从-1到1生成100个点
y1= 2*x + 1
y2 = x**2
plt.figure(figsize=(9,6))
#设置坐标轴
plt.xlim((-1,2))
plt.ylim((-2,3))

plt.xlabel('xxx')
plt.ylabel('yyy')
plt.title('title')

plt.plot(x,y1,color='red',linewidth=1.0,linestyle='--')
plt.plot(x,y2,color='gray',linewidth=2.0,linestyle='-')

plt.xticks(new_data)
plt.yticks([-1,0,1,2,3],['level1','level2','level3','level4','level5'])

ax = plt.gca()
#去掉右边和上边的边框
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

ax.spines['bottom'].set_position(('data',0))#设置x轴的0点值
ax.spines['left'].set_position(('data',0))#设置y轴的0点值

plt.show()

# %% [raw]
# 设置图例

# %%
x = np.linspace(-3,3,100)#从-1到1生成100个点
y1= 2*x + 1
y2 = x**2
plt.figure(figsize=(12,8))
#设置坐标轴
plt.xlim((-1,2))
plt.ylim((-2,3))

plt.xlabel('xxx')
plt.ylabel('yyy')
plt.title('title')
#,逗号是必须的
l1, = plt.plot(x,y1,color='red',linewidth=1.0,linestyle='--')
l2, = plt.plot(x,y2,color='gray',linewidth=2.0,linestyle='-')


# plt.xticks(new_data)
plt.yticks([-1,0,1,2,3],['level1','level2','level3','level4','level5'])
plt.legend(handles=[l1,l2],labels=['test1','test2'],loc='best')
plt.show()

# %% [raw]
# 图像标注

# %%
x = np.linspace(-1,1,100)
y = 2*x +1
plt.plot(x,y,color='red',linewidth=2.0,linestyle='-')

ax =plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

ax.spines['bottom'].set_position(('data',0))
ax.spines['left'].set_position(('data',0))

x0 = 0.5
y0 = 2*x0 + 1
#画点
plt.scatter(x0,y0,s=50,color='b')

#画虚线
plt.plot([x0,x0],[y0,0],'k--',lw=2)

#h画指示标识
plt.annotate(r'$2x+1=%s$' %y0,xy=(x0,y0),xytext=(+30,-30),textcoords='offset points',fontsize=16,
        arrowprops=dict(arrowstyle='->',connectionstyle='arc3,rad=.2'))#以这个点为起点，x方向+30，y方向-30

plt.text(-1,2,r'$this\ is\ the\ text$',fontdict={'size':16,'color':'r'})
plt.show()

# %% [raw]
# 散点图scatter

# %%
plt.scatter(np.arange(10),np.random.rand(10))

# %%
x = np.random.normal(0,1,500)
y = np.random.normal(0,1,500)
plt.scatter(x,y,s=50,c='b',alpha=0.5)
plt.xlim((-2,2))
plt.ylim((-2,2))

plt.yticks(())
plt.xticks(())
plt.show()

# %% [raw]
# 直方图

# %%
x = np.arange(10)
y = 2**x + 1
plt.bar(x,y)
plt.show()

# %%
x = np.arange(10)
y = 2**x + 1
plt.bar(x,-y)
plt.show()

# %%
x = np.arange(10)
y = 2**x + 1
plt.bar(x,y,facecolor='#123450',edgecolor='white')
plt.show()

# %% [raw]
# 给直方图加上数值

# %%
x = np.arange(10)
y = 2**x + 1
plt.bar(x,y,facecolor='#123450',edgecolor='white')
for x,y in zip(x,y):
    plt.text(x-0.6,y,'%.2f'%y)
plt.show()

# %% [raw]
# 绘制等高线图

# %%
def f(x,y):
    return (1-x/2+x**5+y**3)*np.exp(-x**2-y**2)
x = np.linspace(-3,3,100)
y = np.linspace(-3,3,100)

X,Y = np.meshgrid(x,y)
plt.contourf(X,Y,f(X,Y),10,alpha=0.8,cmap=plt.cm.hot)

C = plt.contour(X,Y,f(X,Y),8,colors='black',lw=.5)
plt.clabel(C,inline=True,fontsize=10)
plt.xticks(())
plt.yticks(())
# Out:
# D:\Anaconda3\lib\site-packages\matplotlib\contour.py:1000: UserWarning: The following kwargs were not used by contour: 'lw'
#   s)
# ([], <a list of 0 Text yticklabel objects>)

# %% [raw]
# 3D绘图

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = plt.figure()
ax = Axes3D(fig)

x = np.arange(-4,4,0.25)
y = np.arange(-4,4,0.25)
X,Y = np.meshgrid(x,y)
R = np.sqrt(X**2+Y**2)
Z = np.sin(R)

ax.plot_surface(X,Y,Z,rstride=1,cstride=1,cmap=plt.get_cmap('rainbow'))
ax.contourf(X,Y,Z,zdir='z',offset=-2,cmap='rainbow')
ax.set_zlim(-2,2)
plt.show()

# %% [markdown]
# **上述代码生成的图片可以再ipython中实现，可以切换视图**

# %% [raw]
# 绘制子图

# %%
plt.figure()
plt.subplot(2,2,1)
plt.plot([0,1],[0,1])

plt.subplot(2,2,2)
plt.plot([0,1],[0,1])

plt.subplot(2,2,3)
plt.plot([0,1],[0,1])

plt.subplot(224)
plt.plot([0,1],[0,1])

plt.show()

# %%
plt.figure()
plt.subplot(2,1,1)
plt.plot([0,1],[0,1])

plt.subplot(2,3,4)
plt.plot([0,1],[0,1])

plt.subplot(2,3,5)
plt.plot([0,1],[0,1])

plt.subplot(236)
plt.plot([0,1],[0,1])

plt.show()

# %% [raw]
# 动态图

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import animation

# %%
fig,ax = plt.subplots()

x = np.arange(0,2*np.pi,0.01)
line, = ax.plot(x,np.sin(x))

def  animate(i):
    line.set_ydata(np.sin(x+i/10))
    return line,

def init():
    line.set_ydata(np.sin(x))
    return line,
ani = animation.FuncAnimation(fig=fig,func=animate,init_func=init,interval=20)
plt.show()
